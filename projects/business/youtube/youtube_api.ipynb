# %%
import pandas as pd
import json
import numpy as np
import random
import enum
import re

from urllib.request import urlopen
from urllib.parse import urlencode

# %%
# SETUP
with open("./env.json","r") as f:
    env = json.load(f)
YOUTUBE_API_KEY = env["YOUTUBE_API_KEY"]
PROJECT_NAME = "Neetcode"

# %% [markdown]
# # Classes and helpers

# %%
import pandas as pd
class ByTypes(enum.Enum):
    video_id = "videoId"
    channel_id = "channelId"

class APIYoutubeCommentThread:
    
    def __init__(self, api_json_resource:dict = None):
        assert api_json_resource is not None
        assert api_json_resource["kind"] == "youtube#commentThread"
        
        # self.raw = api_json_resource
        
        
        
        snippet = api_json_resource["snippet"]
        snippet_top_level = snippet["topLevelComment"]["snippet"]   
        self.content = snippet_top_level["textDisplay"].replace("\n", " |n| ")
        self.author_name = snippet_top_level["authorDisplayName"].replace("\n", " |n| ")
        
        self.author_channel_url = snippet_top_level.get("authorChannelUrl", "none")
        
        
        self.video_id = snippet_top_level["videoId"]
        self.viewer_rating = snippet_top_level["viewerRating"]
        self.like_count = int(snippet_top_level["likeCount"])
        self.reply_count = int(snippet["totalReplyCount"])
        self.published_at = snippet_top_level["publishedAt"]
        
    def __str__(self):
        return f"Author:{self.author_name},Content:{self.content},Likes:{self.like_count}.Replies:{self.reply_count}"
    
    def transformToDict(self):
    
        return {
                "author_name": self.author_name,
                "content": self.content,
                "author_channel_url": self.author_channel_url,
                "like_count": self.like_count,
                "reply_count": self.reply_count,
                "published_at": self.published_at,
                "viewer_rating": self.viewer_rating,
                "video_id": self.video_id,
            }
    
        
        

class APIYoutubeVideo:
    
    def __init__(self, api_json_resource:dict = None):
        assert api_json_resource is not None
        assert api_json_resource["kind"] == "youtube#video"
        
        
        # self.raw = api_json_resource
        
        snippet = api_json_resource["snippet"]
        
        self.video_id = api_json_resource["id"]
        self.channel_id = snippet["channelId"]
        self.published_at = snippet["publishedAt"]
        self.title = snippet["title"].replace("\n", " |n| ")
        self.description = snippet["description"].replace("\n", " |n| ")
        
        self.url_thumbnail = snippet["thumbnails"].get("maxres", None)
        
        if self.url_thumbnail is None:
            self.url_thumbnail = snippet["thumbnails"].get("standard", None)
            
            if self.url_thumbnail is None:                
                self.url_thumbnail = snippet["thumbnails"].get("high", None)
                
                if self.url_thumbnail is None:                
                    self.url_thumbnail = snippet["thumbnails"].get("default", None)
        
        
        if self.url_thumbnail is not None:
            self.url_thumbnail =  self.url_thumbnail["url"]
        
        
        self.tags = np.unique(snippet.get("tags",[]))
        self.category_id = int(snippet["categoryId"])
        self.stats_view_count = int(api_json_resource["statistics"]["viewCount"])
        self.stats_like_count = int(api_json_resource["statistics"]["likeCount"])
        self.stats_favorite_count = int(api_json_resource["statistics"]["favoriteCount"])
        self.stats_comment_count = int(api_json_resource["statistics"]["commentCount"])
        
        self.content_details_duration = api_json_resource["contentDetails"]["duration"]
        self.content_details_caption = api_json_resource["contentDetails"]["caption"]
        self.content_details_licensedContent = api_json_resource["contentDetails"]["licensedContent"]
        
        
        
        
    def __str__(self):
        return f"Title:{self.title},Views:{self.stats_view_count},Likes:{self.stats_like_count},Comments:{self.stats_comment_count}"
    
    
    @staticmethod
    def parsePTDurationToSeconds(raw_pt:str):

        seconds = 0
        
        pattern_group_days = "(?:(\d+)D)?"
        pattern_group_hours = "(?:(\d+)H)?"
        pattern_group_minutes = "(?:(\d+)M)?"
        pattern_group_seconds = "(?:(\d+)S)?"
        
        pattern = f"P{pattern_group_days}T{pattern_group_hours}{pattern_group_minutes}{pattern_group_seconds}"
        
        m_date = re.match(pattern, raw_pt)
        
        
        assert m_date is not None
        
        groups = m_date.groups()
        groups_len = len(groups)
        

        i = 1
        time_multiplier = 1
        
        while i <= groups_len:
            g = groups[-i]
            if g is not None:
                seconds += int(g) * time_multiplier
                
            i += 1  
            if i == 4:
                time_multiplier *= 24
            else:
                time_multiplier *= 60
        
        return seconds

    def transformToDict(self):
        
        return {
                "channel_id": self.channel_id,
                "video_id": self.video_id,
                "published_at": self.published_at,
                "title": self.title,
                "description": self.description,
                "url_thumbnail": self.url_thumbnail,
                "tags": ",".join(self.tags),
                "category_id": self.category_id,
                "stats_view_count": self.stats_view_count,
                "stats_like_count": self.stats_like_count,
                "stats_favorite_count": self.stats_favorite_count,
                "stats_comment_count": self.stats_comment_count,
                "content_details_duration_seconds": APIYoutubeVideo.parsePTDurationToSeconds(self.content_details_duration),
                "content_details_caption": 0 if self.content_details_caption == "false" else 1,
                "content_details_licensedContent": 0 if self.content_details_licensedContent == "false" else 1,
        }
        

class APIYoutube:
    
    def __init__(self, API_KEY):
        self.API_KEY = API_KEY
        
    def isValidVideoId(value:str):
        return len(value) == 11
    
    def getCommentThreads(self, by:ByTypes, id:str, part:str="snippet", max_results:int=100, max_pages:int=1):
        assert type(by) == type(ByTypes.video_id)
        assert max_results <= 100
        
        api_endpoint = 'https://www.googleapis.com/youtube/v3/commentThreads'
        
        data = []
        page_count = 0

        api_params = {
            'key': self.API_KEY,
            'part': part,
            'maxResults': max_results,
        }
        
        api_params[by.value] = id

        next_page_token = True

        while next_page_token and page_count <= max_pages:
            
            page_count += 1
            
            encoded_params = urlencode(api_params)
            
            with urlopen(f'{api_endpoint}?{encoded_params}') as response:
                results = json.load(response)
                
                for api_json_resource in results["items"]:
                    # print(api_json_resource)
                    try:
                        data.append(APIYoutubeCommentThread(api_json_resource))
                    except:
                        print("Error with: ", api_json_resource)
                
                next_page_token = results.get('nextPageToken', None)
                api_params['pageToken'] = next_page_token
            

        return data
    
    
    def getVideos(self, id:str, part:str="snippet,statistics,contentDetails"):
        # id can be multiple sepparated by commas
        # suggestions in part only can be retrieved by owner
        api_endpoint = 'https://www.googleapis.com/youtube/v3/videos'
        
        if "," in id:
            assert len(id.split(",")) <= 50

        api_params = {
            'key': self.API_KEY,
            'part': part,
            "id": id
        }
    
        encoded_params = urlencode(api_params)
        
        data = [] 
        
        with urlopen(f'{api_endpoint}?{encoded_params}') as response:
            results = json.load(response)
            
            for api_json_resource in results["items"]:
                # print(api_json_resource)
                data.append(APIYoutubeVideo(api_json_resource))
            

        return data
        


apiYoutube = APIYoutube(YOUTUBE_API_KEY)

# %% [markdown]
# # Retrieve videos

# %%
with open("./videos_ids.txt", "r") as f:
    videos_ids = list(map(lambda s: s.replace("\n", ""), f.readlines()))
    
    
    videos = []
    i = 0
    while i < len(videos_ids):
        index_begin = i
        index_end = min(len(videos_ids), index_begin+49)
        
        assert index_begin != index_end and index_begin <= index_end
        
        videos_ids_str = ",".join(videos_ids[index_begin:(index_end+1)])
        videos.extend(apiYoutube.getVideos(videos_ids_str))
        
        i = index_end + 1
    
    
    print(f"Retrieved {len(videos)} videos")
    

    dictinary_list_videos = []
            


    for video in videos:
        dictinary_list_videos.append(video.transformToDict())


    df_videos = pd.DataFrame.from_dict(dictinary_list_videos)
    df_videos.to_csv(f"{PROJECT_NAME}_videos.csv", index=False)

    del dictinary_list_videos
# Out:
# Retrieved 344 videos

# %%
# Optional: export
"""
df_videos = df_videos[df_videos["channel_id"].apply(lambda s: s == "UC_mYaQAE6-71rjSN6CeCA-g")]
df_videos.to_csv(f"{PROJECT_NAME}_videos.csv", index=False)

channel_id,video_id,published_at,title,description,url_thumbnail,tags,category_id,stats_view_count,stats_like_count,stats_favorite_count,stats_comment_count,content_details_duration_seconds,content_details_caption,content_details_licensedContent

"""

with open("./temp.txt", "w+") as f_in:
    f_in.writelines("\n".join(df_videos["video_id"].values))

# %%
# Number of calls to API
total_comments = 0
max_comments = -1
for video in videos:
    comments_count = int(video.stats_comment_count)
    if comments_count > max_comments:
        max_comments = comments_count
    total_comments += comments_count
print("Total comments: " + str(total_comments), "Calls to API: " + str(total_comments/100))
print("Max number of comments in a video: " + str(max_comments), "Max page calls to api by video: " + str(max_comments/100))
# Out:
# Total comments: 570538 Calls to API: 5705.38
# Max number of comments in a video: 10564 Max page calls to api by video: 105.64

# %%
import time

start_index = 0

quota_max = 7000
quota_left = quota_max
max_pages = 1000
comments = []


assert total_comments/100 < 10000 or quota_left > 10000  # daily quota over reach
assert max_pages > max_comments/100

for i, video in enumerate(videos[start_index:]):
    
    if quota_left - max_pages < 0:
        print("Max quota reach")
        break
    
    assert int(video.stats_comment_count) < 100000
    video_id = video.video_id

    comments_video = apiYoutube.getCommentThreads(ByTypes.video_id, video_id, max_results=100, max_pages=max_pages)
    comments.extend(comments_video)
    quota_left -= (int(len(comments_video)/100) + 1)
    
    print(f"Requested comments: {len(comments)}", f"Video {i} of {len(videos)}", f"Quota left {quota_left}, used {quota_max - quota_left}")
    time.sleep(0.5)

print(f"Retrieved {len(comments)} videos", f"Quota left {quota_left}, used {quota_max - quota_left}")


dictinary_list_comments = []

debug_step = len(comments)//10
for i, comment in enumerate(comments):
    if i > 0 and (i % debug_step == 0 or i == len(comments)-1):
        print("Processed in CSV ", i)
    dictinary_list_comments.append(comment.transformToDict())
            
df_comments = pd.DataFrame.from_dict(dictinary_list_comments)
df_comments.to_csv(f"{PROJECT_NAME}_comments.csv", index=False)   
del dictinary_list_comments
# Out:
# Requested comments: 144 Video 0 of 614 Quota left 6998, used 2
# Requested comments: 548 Video 1 of 614 Quota left 6993, used 7
# Requested comments: 942 Video 2 of 614 Quota left 6989, used 11
# Requested comments: 1000 Video 3 of 614 Quota left 6988, used 12
# Requested comments: 1241 Video 4 of 614 Quota left 6985, used 15
# Requested comments: 1727 Video 5 of 614 Quota left 6980, used 20
# Requested comments: 3086 Video 6 of 614 Quota left 6966, used 34
# Requested comments: 3776 Video 7 of 614 Quota left 6959, used 41
# Requested comments: 3835 Video 8 of 614 Quota left 6958, used 42
# Requested comments: 3961 Video 9 of 614 Quota left 6956, used 44
# Requested comments: 4227 Video 10 of 614 Quota left 6953, used 47
# Requested comments: 4464 Video 11 of 614 Quota left 6950, used 50
# Requested comments: 4544 Video 12 of 614 Quota left 6949, used 51
# Requested comments: 4700 Video 13 of 614 Quota left 6947, used 53
# Requested comments: 4752 Video 14 of 614 Quota left 6946, used 54
# Requested comments: 5250 Video 15 of 614 Quota left 6941, used 59
# Requested comments: 5547 Video 16 of 614 Quota left 6938, used 62
# Requested comments: 5731 Video 17 of 614 Quota left 6936, used 64
# Requested comments: 5830 Video 18 of 614 Quota left 6935, used 65
# Requested comments: 5999 Video 19 of 614 Quota left 6933, used 67
# Requested comments: 7106 Video 20 of 614 Quota left 6921, used 79
# Requested comments: 7209 Video 21 of 614 Quota left 6919, used 81
# Requested comments: 7411 Video 22 of 614 Quota left 6916, used 84
# Requested comments: 7560 Video 23 of 614 Quota left 6914, used 86
# Requested comments: 8413 Video 24 of 614 Quota left 6905, used 95
# Requested comments: 8897 Video 25 of 614 Quota left 6900, used 100
# Requested comments: 9041 Video 26 of 614 Quota left 6898, used 102
# Requested comments: 9269 Video 27 of 614 Quota left 6895, used 105
# Requested comments: 9781 Video 28 of 614 Quota left 6889, used 111
# Requested comments: 9995 Video 29 of 614 Quota left 6886, used 114
# Requested comments: 10094 Video 30 of 614 Quota left 6885, used 115
# Requested comments: 10953 Video 31 of 614 Quota left 6876, used 124
# Requested comments: 11197 Video 32 of 614 Quota left 6873, used 127
# Requested comments: 11329 Video 33 of 614 Quota left 6871, used 129
# Requested comments: 11485 Video 34 of 614 Quota left 6869, used 131
# Requested comments: 13248 Video 35 of 614 Quota left 6851, used 149
# Requested comments: 13343 Video 36 of 614 Quota left 6850, used 150
# Requested comments: 13383 Video 37 of 614 Quota left 6849, used 151
# Requested comments: 13395 Video 38 of 614 Quota left 6848, used 152
# Requested comments: 13718 Video 39 of 614 Quota left 6844, used 156
# Requested comments: 13980 Video 40 of 614 Quota left 6841, used 159
# Requested comments: 14447 Video 41 of 614 Quota left 6836, used 164
# Requested comments: 16804 Video 42 of 614 Quota left 6812, used 188
# Requested comments: 17543 Video 43 of 614 Quota left 6804, used 196
# Requested comments: 17698 Video 44 of 614 Quota left 6802, used 198
# Requested comments: 18125 Video 45 of 614 Quota left 6797, used 203
# Requested comments: 18417 Video 46 of 614 Quota left 6794, used 206
# Requested comments: 19050 Video 47 of 614 Quota left 6787, used 213
# Requested comments: 19470 Video 48 of 614 Quota left 6782, used 218
# Requested comments: 20047 Video 49 of 614 Quota left 6776, used 224
# Requested comments: 20348 Video 50 of 614 Quota left 6772, used 228
# Requested comments: 20399 Video 51 of 614 Quota left 6771, used 229
# Requested comments: 21428 Video 52 of 614 Quota left 6760, used 240
# Requested comments: 21584 Video 53 of 614 Quota left 6758, used 242
# Requested comments: 22676 Video 54 of 614 Quota left 6747, used 253
# Requested comments: 23167 Video 55 of 614 Quota left 6742, used 258
# Requested comments: 23546 Video 56 of 614 Quota left 6738, used 262
# Requested comments: 23718 Video 57 of 614 Quota left 6736, used 264
# Requested comments: 24563 Video 58 of 614 Quota left 6727, used 273
# Requested comments: 25134 Video 59 of 614 Quota left 6721, used 279
# Requested comments: 27820 Video 60 of 614 Quota left 6694, used 306
# Requested comments: 28332 Video 61 of 614 Quota left 6688, used 312
# Requested comments: 28939 Video 62 of 614 Quota left 6681, used 319
# Requested comments: 28993 Video 63 of 614 Quota left 6680, used 320
# Requested comments: 29112 Video 64 of 614 Quota left 6678, used 322
# Requested comments: 29248 Video 65 of 614 Quota left 6676, used 324
# Requested comments: 29460 Video 66 of 614 Quota left 6673, used 327
# Requested comments: 30123 Video 67 of 614 Quota left 6666, used 334
# Requested comments: 30195 Video 68 of 614 Quota left 6665, used 335
# Requested comments: 30763 Video 69 of 614 Quota left 6659, used 341
# Requested comments: 30852 Video 70 of 614 Quota left 6658, used 342
# Requested comments: 31266 Video 71 of 614 Quota left 6653, used 347
# Requested comments: 31334 Video 72 of 614 Quota left 6652, used 348
# Requested comments: 33020 Video 73 of 614 Quota left 6635, used 365
# Requested comments: 33047 Video 74 of 614 Quota left 6634, used 366
# Requested comments: 33100 Video 75 of 614 Quota left 6633, used 367
# Requested comments: 35839 Video 76 of 614 Quota left 6605, used 395
# Requested comments: 36085 Video 77 of 614 Quota left 6602, used 398
# Requested comments: 36104 Video 78 of 614 Quota left 6601, used 399
# Requested comments: 36155 Video 79 of 614 Quota left 6600, used 400
# Requested comments: 36306 Video 80 of 614 Quota left 6598, used 402
# Requested comments: 36657 Video 81 of 614 Quota left 6594, used 406
# Requested comments: 36829 Video 82 of 614 Quota left 6592, used 408
# Requested comments: 37458 Video 83 of 614 Quota left 6585, used 415
# Requested comments: 37515 Video 84 of 614 Quota left 6584, used 416
# Requested comments: 37596 Video 85 of 614 Quota left 6583, used 417
# Requested comments: 37922 Video 86 of 614 Quota left 6579, used 421
# Requested comments: 38142 Video 87 of 614 Quota left 6576, used 424
# Requested comments: 38816 Video 88 of 614 Quota left 6569, used 431
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_57702/491929573.py in <module>
#      21     video_id = video.video_id
#      22
# ---> 23     comments_video = apiYoutube.getCommentThreads(ByTypes.video_id, video_id, max_results=100, max_pages=max_pages)
#      24     comments.extend(comments_video)
#      25     quota_left -= (int(len(comments_video)/100) + 1)
#
# /tmp/ipykernel_57702/357744764.py in getCommentThreads(self, by, id, part, max_results, max_pages)
#     189             encoded_params = urlencode(api_params)
#     190
# --> 191             with urlopen(f'{api_endpoint}?{encoded_params}') as response:
#     192                 results = json.load(response)
#     193
#
# ~/anaconda3/lib/python3.8/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/anaconda3/lib/python3.8/urllib/request.py in open(self, fullurl, data, timeout)
#     523
#     524         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~/anaconda3/lib/python3.8/urllib/request.py in _open(self, req, data)
#     540
#     541         protocol = req.type
# --> 542         result = self._call_chain(self.handle_open, protocol, protocol +
#     543                                   '_open', req)
#     544         if result:
#
# ~/anaconda3/lib/python3.8/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~/anaconda3/lib/python3.8/urllib/request.py in https_open(self, req)
#    1391
#    1392         def https_open(self, req):
# -> 1393             return self.do_open(http.client.HTTPSConnection, req,
#    1394                 context=self._context, check_hostname=self._check_hostname)
#    1395
#
# ~/anaconda3/lib/python3.8/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1352             except OSError as err: # timeout error
#    1353                 raise URLError(err)
# -> 1354             r = h.getresponse()
#    1355         except:
#    1356             h.close()
#
# ~/anaconda3/lib/python3.8/http/client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~/anaconda3/lib/python3.8/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~/anaconda3/lib/python3.8/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~/anaconda3/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/anaconda3/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# Out:
# 197237

# %%
df_comments.head()
# Out:
#          author_name                                            content  \
# 0        Code Bullet  Hey guys<br> I&#39;ve uploaded the source code...
# 1            Ariztax         This is so incredibly satisfying to watch.
# 2        bommer yeet                                               Nice
# 3       PoofyHairGuy  I remember watching these videos. I never real...
# 4  Random_Gachatuber  You could make a cycle, just have the snake go...
#
#                                   author_channel_url  like_count  \
# 0  http://www.youtube.com/channel/UC0e3QhIYukixgh...        1374
# 1  http://www.youtube.com/channel/UC-mM7cY_WeRFyR...           1
# 2  http://www.youtube.com/channel/UC6nHg0Nu-6Wm4G...           0
# 3  http://www.youtube.com/channel/UCRHqQfvTgwsS0l...           3
# 4  http://www.youtube.com/channel/UCg-3hhvf2EoVq0...           0
#
#            published_at viewer_rating     video_id
# 0  2018-02-08T04:24:26Z          none  3bhP7zulFfY
# 1  2022-03-13T09:05:19Z          none  3bhP7zulFfY
# 2  2022-01-21T02:39:58Z          none  3bhP7zulFfY
# 3  2022-01-18T08:25:15Z          none  3bhP7zulFfY
# 4  2022-01-17T20:01:47Z          none  3bhP7zulFfY

# %%
df_comments.sort_values(["like_count"], ascending=False).head()
# TODO: repair comments in multiple lines

df_comments[df_comments["like_count"] > 10].sort_values(["like_count"], ascending=False).to_csv("CodeBulletGags.csv",index=False)

# %%
df_comments[["author_name","video_id"]].groupby(["author_name"]).agg("count").sort_values(["video_id"], ascending=False).head(10)
# Out:
#              video_id
# author_name
# Alex               81
# David              56
# James              52
# John Smith         46
# Ben                45
# Michael            45
# Ryan               44
# Andrew             43
# Daniel             42
# Chris              41

# %%
df_comments[["author_name","like_count"]].groupby(["author_name"]).sum().sort_values(["like_count"], ascending=False).head(10)
# Out:
#                   like_count
# author_name
# CryspyPasta            62288
# Justin Y.              46055
# Taikamuna              44823
# Nicholas Nguyen        42867
# shinnyii               42583
# Dani                   40500
# Code Bullet            32977
# Taylor Youngreen       29154
# atenahena              28321
# KRLA                   25888
